# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0daeb7c4-4261-4dfd-861e-8a4b3cf7af19" name="files[]" multiple disabled />
#      <output id="result-0daeb7c4-4261-4dfd-861e-8a4b3cf7af19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import pandas as pd

# %%
pd.read_csv('bridge.xlsx')
# Out:
#        E1  M   3  CRAFTS   HIGHWAY       ?  ...  N  THROUGH   WOOD   SHORT  S WOOD.1
# 0      E2  A  25  CRAFTS   HIGHWAY  MEDIUM  ...  N  THROUGH   WOOD   SHORT  S   WOOD
# 1      E3  A  39  CRAFTS  AQUEDUCT       ?  ...  N  THROUGH   WOOD       ?  S   WOOD
# 2      E5  A  29  CRAFTS   HIGHWAY  MEDIUM  ...  N  THROUGH   WOOD   SHORT  S   WOOD
# 3      E6  M  23  CRAFTS   HIGHWAY       ?  ...  N  THROUGH   WOOD       ?  S   WOOD
# 4      E7  A  27  CRAFTS   HIGHWAY   SHORT  ...  N  THROUGH   WOOD  MEDIUM  S   WOOD
# ..    ... ..  ..     ...       ...     ...  ... ..      ...    ...     ... ..    ...
# 102   E84  A  24  MODERN   HIGHWAY   SHORT  ...  G  THROUGH  STEEL  MEDIUM  F   ARCH
# 103   E91  O  44  MODERN   HIGHWAY    LONG  ...  G  THROUGH  STEEL    LONG  F   ARCH
# 104   E90  M   7  MODERN   HIGHWAY   SHORT  ...  G  THROUGH  STEEL    LONG  F   ARCH
# 105  E100  O  43  MODERN   HIGHWAY       ?  ...  G        ?      ?       ?  F      ?
# ...
