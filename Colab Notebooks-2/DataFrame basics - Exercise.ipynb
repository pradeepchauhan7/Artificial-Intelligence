# %%
import pandas as pd
df = pd.DataFrame([[0.23,'f1'],[5.36,'f2']],
                  index = list('pq'),
                    columns = list('ab'))

# %%
df
# Out:
#       a   b
# p  0.23  f1
# q  5.36  f2

# %%
df = df.rename(columns={'a' : 'A'})

# %%
df['c'] = [5,6]

# %%
df
# Out:
#       A   b  c
# p  0.23  f1  5
# q  5.36  f2  6

# %%
df['A'] = df['A'].astype('complex')

# %%
df
# Out:
#                     A   b  c
# p  0.230000+0.000000j  f1  5
# q  5.360000+0.000000j  f2  6

# %%
lst = ['f30','f50','f2','f0']

# %%
for i in df.index:
    if (df['A'][i] in lst or df['b'][i] in lst or df['c'][i] in lst):
      print(df['A'][i], df['b'][i], df['c'][i])
# Out:
# (5.36+0j) f2 6
