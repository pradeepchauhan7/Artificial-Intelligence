# %%
# pip install keras-lr-finder
# pip install keras-vis
pip install scikit-learn

# %%
import imageio
import keras
# import keras-lr-finder
# import keras-vis
import matplotlib
import mlxtend
import numpy 
import pandas
# import pillow
# import scikit-learn
import scipy 
import tensorboard
import tensorflow
import vis
