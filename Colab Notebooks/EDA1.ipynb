# %%
https://apc01.safelinks.protection.outlook.com/?url=https%3A%2F%2Finfosys.webex.com%2Frecordingservice%2Fsites%2Finfosys%2Frecording%2Fplayback%2F71117f4901fa4490be2ff2acf815f51d&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7C6f0afc18b763484e1fec08d8022e09a8%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C0%7C637261744044313436&sdata=E6aEqExmT4OkdNmnZo9AiaYPSb6N8BQ42vc3z7kPQcc%3D&reserved=0
Recording password: rW4iDNrJ
https://apc01.safelinks.protection.outlook.com/?url=https%3A%2F%2Finfosys.webex.com%2Frecordingservice%2Fsites%2Finfosys%2Frecording%2Fplayback%2F1dad5359c1d44b598eeab0fc38113d5b&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7Ca43ae68dd7fd4477659008d802ce4b57%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C0%7C637262432357712821&sdata=VITXLNNJORANGC1R%2BI62nfCevT2cqA%2Bj5JbbS9BXt00%3D&reserved=0
Recording password: JnMNPU8x 
https://apc01.safelinks.protection.outlook.com/?url=https%3A%2F%2Finfosys.webex.com%2Frecordingservice%2Fsites%2Finfosys%2Frecording%2Fplayback%2Fd32235e8878f46f7841f0a2d8e3a52ea&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7Cb2f0194c46744e7a084808d806bbf582%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C0%7C637266751638677414&sdata=6ifSCfinJG6HNc7WsHxLmbjDIl12VzhrKWGxR59Sai0%3D&reserved=0
Recording password: DmweHzr5 
https://apc01.safelinks.protection.outlook.com/?url=https%3A%2F%2Finfosys.webex.com%2Finfosys%2Fldr.php%3FRCID%3D8dd97aba560b46958ba7911df4f7c432&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7C078df64feb4640c6ce0e08d80965896d%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C0%7C637269678984856033&sdata=V1UOfLFNhmn9lMOULS18%2FabHoHR%2Fzul6CmZV51GSsJY%3D&reserved=0
4MnateP3
https://apc01.safelinks.protection.outlook.com/?url=https%3A%2F%2Finfosys.webex.com%2Fmeet%2Fpratik.lembhe&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7Ce4e767db709f4319b26d08d80d29ef12%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C0%7C637273821079277516&sdata=5qR19u3H0JHcq7fWBoUp%2FmkeGG4vqgIXvlKVW3BFJGU%3D&reserved=0import numpy as np
ec2-18-195-96-51.eu-central-1.compute.amazonaws.com
3IzIXmVqyiaD7v2j4G2FiIxL
https://apc01.safelinks.protection.outlook.com/?url=http%3A%2F%2Furl9251.event.elastic.co%2Fls%2Fclick%3Fupn%3Dvl5FT-2BF4CCqAaRtYG4M5wI5sD5EqQI8cbVZW5B0SLJUEKLV9QRlFryEH0GNVivwP977uZsIsm-2FbWm68WfuUuL8ZUsG8-2FVfceit6x9nWEdlY-3DtocJ_r2Tf9EUfGSeEpXK69vz33E2-2B0lyasFQISfPRqM-2FO02eqqBhNzquNXuE4EgVdzah0jb-2BN1uaQudkP1vs4KypFrpvbV9ctuqlLDMTBy-2BaU2DVw6gKjcxH1Ne5yvMY-2BUUhAgKgAhYC7Dq4FSiiQyXDHDloE0OEmKk7Bn4p9ySPa6qTpgoTs15Z88205J2UtkfmW1wRcDSvlNfZgBGiZWjilHNA59RLw-2BLCJt4OKUzWIyUYCGZRpT6yQEaJjWrU6qpmS8GBxF6HWAtq2XxxP5gHJ2-2Fvm2TrfFHKqwK1Ruy5P0rFuiJZkJdSzaMv2V4O1i6ZmlDf9xivzeyeEkEjmVtD5KDdehFD6SHW7-2Fx7MisK9II-2Fxd-2FpFmkFS2iFW4INDIT2fqOmaM508vj8atydSkADCE4xD6W2DfSMN-2BcRZbQH9ViiUYHjdlklusxgj86yXw7NU&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7C42e7230c0e1d4ae8300808d81c2a01b8%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C1%7C637290314031953892&sdata=EuUGe1ZkhKD7OdRHTbnIxwWST81rHjbf0G5Tse%2FExwA%3D&reserved=0
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
https://apc01.safelinks.protection.outlook.com/?url=https%3A%2F%2Finfosys.webex.com%2Finfosys%2Fldr.php%3FRCID%3Df60d6ffdeeae44c3b04f9c364723564c&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7C065c99a72b61428a8e1a08d81db64fc8%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C0%7C637292016156743301&sdata=LcvVJuRYpikSXHuH%2BdlGYz7JU%2BuW0FHWICEORNqw1Lk%3D&reserved=0
MjUmz6dR
https://apc01.safelinks.protection.outlook.com/?url=https%3A%2F%2Finfosys.webex.com%2Finfosys%2Fldr.php%3FRCID%3D1ff9843559884fc584d4a0a8c94cf4aa&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7C670d8d604f374341851608d81e9cd18b%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C0%7C637293006159755309&sdata=nXmenaBPAbWbsQNOXNQkCJFICSt8HqCdGPpmKg6WB4Y%3D&reserved=0
GejReSx9
https://bit.ly/2AqEYXG 
https://apc01.safelinks.protection.outlook.com/?url=http%3A%2F%2Furl9251.event.elastic.co%2Fls%2Fclick%3Fupn%3Dvl5FT-2BF4CCqAaRtYG4M5wI5sD5EqQI8cbVZW5B0SLJUEKLV9QRlFryEH0GNVivwP977uZsIsm-2FbWm68WfuUuL8ZUsG8-2FVfceit6x9nWEdlY-3DtocJ_r2Tf9EUfGSeEpXK69vz33E2-2B0lyasFQISfPRqM-2FO02eqqBhNzquNXuE4EgVdzah0jb-2BN1uaQudkP1vs4KypFrpvbV9ctuqlLDMTBy-2BaU2DVw6gKjcxH1Ne5yvMY-2BUUhAgKgAhYC7Dq4FSiiQyXDHDloE0OEmKk7Bn4p9ySPa6qTpgoTs15Z88205J2UtkfmW1wRcDSvlNfZgBGiZWjilHNA59RLw-2BLCJt4OKUzWIyUYCGZRpT6yQEaJjWrU6qpmS8GBxF6HWAtq2XxxP5gHJ2-2Fvm2TrfFHKqwK1Ruy5P0rFuiJZkJdSzaMv2V4O1i6ZmlDf9xivzeyeEkEjmVtD5KDdehFD6SHW7-2Fx7MisK9II-2Fxd-2FpFmkFS2iFW4INDIT2fqOmaM508vj8atydSkADCE4xD6W2DfSMN-2BcRZbQH9ViiUYHjdlklusxgj86yXw7NU&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7C42e7230c0e1d4ae8300808d81c2a01b8%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C1%7C637290314031953892&sdata=EuUGe1ZkhKD7OdRHTbnIxwWST81rHjbf0G5Tse%2FExwA%3D&reserved=0


https://apc01.safelinks.protection.outlook.com/?url=https%3A%2F%2Finfosys.webex.com%2Finfosys%2Fldr.php%3FRCID%3Df60d6ffdeeae44c3b04f9c364723564c&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7C004e9ec3d06b4e1c914c08d81e5467fb%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C0%7C637292696526326439&sdata=2HQDfA1uRvWz7S8tawwQwodSo3fiSyiznXOEO8EsrMs%3D&reserved=0
MjUmz6dR
https://apc01.safelinks.protection.outlook.com/?url=https%3A%2F%2Finfosys.webex.com%2Finfosys%2Fldr.php%3FRCID%3D1ff9843559884fc584d4a0a8c94cf4aa&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7C223097884ff94b71dbc608d81e85171a%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C0%7C637292904249175869&sdata=9exjXs7vhj0QYFRsVRpByhyr8QY54V%2FQO5oSYwrXVtk%3D&reserved=0
GejReSx9
https://apc01.safelinks.protection.outlook.com/?url=https%3A%2F%2Finfosys.webex.com%2Finfosys%2Fldr.php%3FRCID%3D7b38cd4cba9a459f8b69f52a1145d9e6&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7C36d540d2c1f64c79b0b108d81f45dfea%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C0%7C637293732252210017&sdata=09zz5MpQjycdEvQMH2qsXNnTKxYUmENK41B9%2B9olFXE%3D&reserved=0
Xcs8SPQh
# Out:
#   File "<ipython-input-1-8ffa54885661>", line 1
#     https://apc01.safelinks.protection.outlook.com/?url=https%3A%2F%2Finfosys.webex.com%2Fmeet%2Fpoonamjaiprakash.k&data=02%7C01%7Cpradeep.chauhan03%40infosys.com%7Cbd7cc13a881d474a08c908d7fd52d7a0%7C63ce7d592f3e42cda8ccbe764cff5eb6%7C1%7C0%7C637256405170716719&sdata=rKBklrNXW2Eyl8asoEvPnkp6UUjt4l60Aw7jpT3ZcYo%3D&reserved=0
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# Team,
#
# Hope you all have completed Splunk training.
#
# As a part of this training, I am sharing the details of Splunk Assignment (“Point of Sale”), which you need to complete in next week.
#
# Details Contains:
# -	Log file
# -	Lookups (Master Data)
# -	Use cases dashboard wise
#
# Next steps:
# -	Any one take ownership of indexing logs + creating lookup only once
# -	_time mapping as date given in the logs
# -	Index name and sourctype name should be logical
# -	Same indexed data will be used to build dashboards
# -	Create 4 apps with your name e.g. POS_PC (For Pradeep)
# -	And create all dashboards under your respective app only
# -	Next week Thu/Fri will have a review.
# -	You can also come up with new use cases based upon the logs analysis

# %%
# import zipfile
# with zipfile.ZipFile('./drive/My Drive/Datasets/Data.zip') as zip:
#   zip.extractall(path = './drive/My Drive/Datasets')

# %%
user_rating = pd.read_csv('./drive/My Drive/Datasets/Data/user_rating.csv')
user_rating.head()
# Out:
#   userID  placeID  food_rating  service_rating
# 0  U1077   135085            2               2
# 1  U1077   135038            2               1
# 2  U1077   132825            2               2
# 3  U1077   135060            2               2
# 4  U1068   135104            1               2

# %%
consumer_survey = pd.read_excel('./drive/My Drive/Datasets/Data/consumer_survey.xlsx')
consumer_survey.head()
# Out:
#    gender smoker     drink_level  ...  income FRVPM AERPM
# 0    male  False      abstemious  ...  medium    12  2976
# 1  female  False      abstemious  ...     low    12  3648
# 2  female  False  social drinker  ...     low     3  1461
# 3    male  False      abstemious  ...  medium    18  4014
# 4  female  False      abstemious  ...  medium    15  3045
#
# [5 rows x 14 columns]

# %%
restaurant_parking = pd.read_excel('./drive/My Drive/Datasets/Data/restaurant_parking.xlsx')
restaurant_parking.head()
# Out:
#    placeID parking_lot
# 0   135111      public
# 1   135110        none
# 2   135109        none
# 3   135108        none
# 4   135107        none

# %%
dining_preferences = pd.read_excel('./drive/My Drive/Datasets/Data/dining_preferences.xlsx')
dining_preferences.head()
# Out:
#    Year  Dine_In  Home_Delivery
# 0  1990     5649              0
# 1  1991     5539              0
# 2  1992     5760            104
# 3  1993     6509             76
# 4  1994     6982            156

# %%
# pip install mdbtools

# %%
# cd My Drive/Datasets/Data/
# path = './drive/My Drive/Datasets/Data/restaurant_cuisine.accdb'
# des_path = './drive/My Drive/Datasets/Data/restaurant_cuisine.csv'
# mdb-export restaurant_cuisine.accdb Table> restaurant_cuisine.csv

# %%
# import pypyodbc
# path = './drive/My Drive/Datasets/Data/restaurant_cuisine.accdb'
# conn_str = (r'Driver={Microsoft Access Driver (*.mdb, *.accdb)}; DBQ=%s;' %path)
# conn  = pypyodbc.connect(conn_str)
# cuisine = pd.read_sql('select * from cuisine', conn)
# conn.close()

# cuisine.head()

# %%
restaurant_cuisine = pd.read_csv('./drive/My Drive/Datasets/Data/restaurant_cuisine.csv')
restaurant_cuisine.head()
# Out:
#    placeID        Rcuisine
# 0   135110         Spanish
# 1   135109         Italian
# 2   135107  Latin_American
# 3   135106         Mexican
# 4   135105       Fast_Food

# %%
restaurant_details = pd.read_csv('./drive/My Drive/Datasets/Data/restaurant_details.csv')
restaurant_details.head()
# Out:
#    PLACEID                              NAME  ...  REGION AVERAGE_DINE_IN_PER_MONTH
# 0   134999                  Kiku Cuernavaca   ...   West                      677.0
# 1   132825                  puesto de tacos   ...   West                      561.0
# 2   135106       El Rincon de San Francisco   ...   East                      743.0
# 3   132667   little pizza Emilio Portes Gil   ...   East                      546.0
# 4   132613                    carnitas_mata   ...   East                      697.0
#
# [5 rows x 13 columns]

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('./drive/My Drive/Datasets/Data/reviews.xml')
root = tree.getroot()
print(root.tag, "ID", root.attrib['id'])
# Out:
# Restaurant ID 41955207

# %%
restaurantDict = {}
reviewDict = {}
specialFeaturesList = []
reviewsList = []

for elem in root:
  restaurantDict.update({elem.tag : elem.text})
  for subelem in elem:
    if elem.tag == "SpecialFeatures":
      specialFeaturesList.append(subelem.text)
      restaurantDict.update({"SpecialFeatures" : specialFeaturesList})
    if elem.tag == "Reviews":
      reviewDict = {}
      reviewDict.update({"ReviewId" : subelem.attrib['id']})
      for subsubelem in subelem:
        reviewDict.update({subsubelem.tag : subsubelem.text})
      reviewsList.append(reviewDict)
      restaurantDict.update({"Reviews" : reviewsList})

# %%
print(root.tag, "Id :", root.attrib['id'])
print('--------------------------------------------------------------------------------------------------------------------------------------')

for key,val in restaurantDict.items():
  if key == "Reviews":
    print(key,":")
    for reviews in val:
      for keyR , valR in reviews.items():
        print(keyR,":",valR)
      print('\n--------------------------------------------------------------------------------------------------------------------------------------')
  else:
    print(key,":",val)
# Out:
# Restaurant Id : 41955207
# --------------------------------------------------------------------------------------------------------------------------------------
# Name : Staghorn Steakhouse
# ZipCode : 10018
# Cuisines : Seafood, Steakhouse
# PriceLevel : None
# Hours : None
# Payment : None
# DressCode : None
# SpecialFeatures : ['Notable Wine List', 'Business Dining', 'Romantic Dining', 'Group Dining', 'Fine Dining']
# PromptSeating : yes
# MakeReservation : yes
# Romantic : yes
# GoodForKids : no
# GoodForGroups : yes
# Reviews :
# ReviewId : 1741211
# UserType : Customer
# Title : like eating in a funeral parlor!
# Username : pauli68
# Date : 07/28/2006
# TotalRatedHelpful :
#
# TotalRated :
#
# ...

# %%
feedback = pd.read_table('./drive/My Drive/Datasets/Data/feedback.txt', names=["Reviews"])
feedback.head()
# Out:
#                                              Reviews
# 0             The food for our event was delicious .
# 1   The food in the lounge was great and very fre...
# 2   As far as food, walk a few blocks toward Mich...
# 3   The Palm resturant in the hotel had some spec...
# 4   Took the charge of the minibar which we had u...

# %%
drug_df = pd.read_csv('./drive/My Drive/Datasets/Data/drug.tsv', delimiter='\t')
drug_df.head()
# Out:
#    Unnamed: 0  ...                                     commentsReview
# 0        2202  ...  monitor blood pressure , weight and asses for ...
# 1        3117  ...  I Hate This Birth Control, I Would Not Suggest...
# 2        1146  ...  I took 2 pills at the onset of my menstrual cr...
# 3        3947  ...  I was given Prilosec prescription at a dose of...
# 4        1951  ...                                          See above
#
# [5 rows x 9 columns]

# %%
feedback_df = pd.read_table('./drive/My Drive/Datasets/Data/opinion.txt', names = ['Reviews', 'ID'], delimiter='.')
feedback_df.reset_index(inplace=True)
feedback_df.drop(columns='ID', inplace=True)
# feedback_df.set_index('ID', inplace = True)
feedback_df.rename(columns={'index' : 'ID'}, inplace=True)
feedback_df.head()
# Out:
#    ID                                            Reviews
# 0   0              The food for our event was delicious
# 1   1   The food in the lounge was great and very fre...
# 2   2   As far as food, walk a few blocks toward Mich...
# 3   3   The Palm resturant in the hotel had some spec...
# 4   4   Took the charge of the minibar which we had u...

# %% [markdown]
# ## Preprocess Data
# # clean data
# # check for inconsistency in data

# %%
restaurant_details['STATE'].value_counts()
# Out:
#  SLP                 50
#  Morelos             19
#                      18
#  San Luis Potosi     14
#  tamaulipas           9
#  Tamaulipas           7
#  san luis potosi      4
#  slp                  2
#  mexico               2
#  S.L.P.               2
#  morelos              1
#  san luis potos       1
#  s.l.p.               1
# Name: STATE, dtype: int64

# %%
restaurant_details['STATE'] = ["Tamaulipas" if x in [" Tamaulipas ", " tamaulipas "] else x for x in restaurant_details["STATE"]]
restaurant_details['STATE'] = ["Morelos" if x in [" morelos ", " Morelos "] else x for x in restaurant_details["STATE"]]
restaurant_details['STATE'] = ["San Luis Potosi" if x in [" s.l.p. ", " SLP ", " san luis potos ", " slp ", " S.L.P. ", " san luis potosi "] else x for x in restaurant_details["STATE"]]
restaurant_details['STATE'] = ["Mexico" if x in [" mexico ", " Mexico "] else x for x in restaurant_details["STATE"]]

# %%
restaurant_details['STATE'].value_counts()
# Out:
# San Luis Potosi      60
# Morelos              20
#                      18
# Tamaulipas           16
#  San Luis Potosi     14
# Mexico                2
# Name: STATE, dtype: int64

# %%
restaurant_details["COUNTRY"].value_counts()
# Out:
#  Mexico     89
#             24
#  mexico     13
#  ?           3
#  NA          1
# Name: COUNTRY, dtype: int64

# %%
restaurant_details['COUNTRY'] = ["Mexico" if x in [" mexico ", " Mexico "] else x for x in restaurant_details["COUNTRY"]]
restaurant_details['COUNTRY'].value_counts()
# Out:
# Mexico    102
#            24
#  ?          3
#  NA         1
# Name: COUNTRY, dtype: int64

# %%
print(len(consumer_survey.loc[consumer_survey.FRVPM < 0]))
print(len(consumer_survey.loc[consumer_survey.AERPM < 0]))
# Out:
# 0
# 0

# %%
d = [-1, -2 , 4,5,7]
a = map(lambda x : 0 if x < 0 else x, d)
print(list(a))
# Out:
# [0, 0, 4, 5, 7]

# %% [markdown]
# ## Delete Data
# ## Delete Row

# %%
consumer_survey.shape
consumer_survey.replace('?', np.NAN, inplace=True)
consumer_survey.dropna(axis = 0, inplace=True, thresh=13)
consumer_survey.reset_index(inplace=True, drop=True)
consumer_survey.shape
# Out:
# (134, 14)

# %%
consumer_survey.head()
# Out:
#    gender smoker     drink_level  ...  income FRVPM AERPM
# 0    male  False      abstemious  ...  medium    12  2976
# 1  female  False      abstemious  ...     low    12  3648
# 2  female  False  social drinker  ...     low     3  1461
# 3    male  False      abstemious  ...  medium    18  4014
# 4  female  False      abstemious  ...  medium    15  3045
#
# [5 rows x 14 columns]

# %%
missing_values = ['?', '  ', 'NA']
for i in missing_values:
  restaurant_details.replace(i, np.NAN, inplace=True)
restaurant_details.dropna(axis=0, inplace=True, thresh=11)
restaurant_details.shape
# restaurant_details.reset_index(inplace=True, drop=True)
# Out:
# (110, 13)

# %%
restaurant_details.dropna(axis = 1, inplace=True, thresh=60 * 1.1)
restaurant_details.shape
# Out:
# (110, 12)

# %%
print(restaurant_details.columns)
# Out:
# Index(['PLACEID', 'NAME', 'ADDRESS', 'STATE', 'COUNTRY', 'ALCOHOL',
#        'SMOKING_AREA', 'PRICE', 'AREA', 'OTHER_SERVICES', 'REGION',
#        'AVERAGE_DINE_IN_PER_MONTH'],
#       dtype='object')

# %%
from sklearn.impute import SimpleImputer
df = restaurant_details.loc[:, ['COUNTRY']]
df[df.isna().any(axis = 1)].index.tolist()
# Out:
# [46, 88, 98, 103]

# %%
restaurant_details.loc[[46, 88, 98, 103], ["COUNTRY"]]
# Out:
#     COUNTRY
# 46      NaN
# 88      NaN
# 98      NaN
# 103     NaN

# %%
country_array = np.array(restaurant_details["COUNTRY"])
imputer = SimpleImputer(strategy='constant', fill_value= "Mexico")
restaurant_details["COUNTRY"] = imputer.fit_transform(country_array.reshape(-1,1))
restaurant_details.loc[[46, 88, 98, 103], ["COUNTRY"]]
country_array.shape
# Out:
# (110,)

# %%
df = consumer_survey.loc[:, ['transport']]
df[df.isna().any(axis = 1)].index.tolist()
# Out:
# [29, 37, 119]

# %%
consumer_survey.loc[[29, 37, 119], ['transport']]
# Out:
#     transport
# 29        NaN
# 37        NaN
# 119       NaN

# %%
consumer_survey['transport'].value_counts()
# Out:
# public       82
# car owner    35
# on foot      14
# Name: transport, dtype: int64

# %%
consumer_survey['transport'].mode()[0]
# Out:
# 'public'

# %%
transport_array = np.array(consumer_survey['transport'])
imputer = SimpleImputer(strategy='most_frequent')
consumer_survey['transport'] = imputer.fit_transform(transport_array.reshape(-1,1))
consumer_survey.loc[[29, 37, 119], ['transport']]
# Out:
#     transport
# 29     public
# 37     public
# 119    public

# %%
restaurant_details.AVERAGE_DINE_IN_PER_MONTH = pd.to_numeric(restaurant_details.AVERAGE_DINE_IN_PER_MONTH)

# %%
df = restaurant_details.loc[:, ["AVERAGE_DINE_IN_PER_MONTH"]]
df.loc[df.isna().any(axis = 1)].index.tolist()
# Out:
# [20, 25, 33, 42]

# %%
restaurant_details.loc[[20, 25, 33, 42], ["AVERAGE_DINE_IN_PER_MONTH", "STATE"]]
# Out:
#     AVERAGE_DINE_IN_PER_MONTH            STATE
# 20                        NaN  San Luis Potosi
# 25                        NaN  San Luis Potosi
# 33                        NaN  San Luis Potosi
# 42                        NaN  San Luis Potosi

# %%
restaurant_details[["AVERAGE_DINE_IN_PER_MONTH"]].mean()
# Out:
# AVERAGE_DINE_IN_PER_MONTH    652.518868
# dtype: float64

# %%
average_dine_in_per_month_array = np.array(restaurant_details["AVERAGE_DINE_IN_PER_MONTH"])
imputer = SimpleImputer(strategy= "mean")
restaurant_details['AVERAGE_DINE_IN_PER_MONTH_MEAN_IMPUTED'] = imputer.fit_transform(average_dine_in_per_month_array.reshape(-1,1))
restaurant_details.loc[[20, 25, 33, 42], ["AVERAGE_DINE_IN_PER_MONTH_MEAN_IMPUTED", "STATE"]]
# Out:
#     AVERAGE_DINE_IN_PER_MONTH_MEAN_IMPUTED            STATE
# 20                              652.518868  San Luis Potosi
# 25                              652.518868  San Luis Potosi
# 33                              652.518868  San Luis Potosi
# 42                              652.518868  San Luis Potosi

# %%
restaurant_details[["AVERAGE_DINE_IN_PER_MONTH", "STATE"]].groupby('STATE').mean()
# Out:
#                    AVERAGE_DINE_IN_PER_MONTH
# STATE
#  San Luis Potosi                  699.571429
# Mexico                            859.000000
# Morelos                           643.150000
# San Luis Potosi                   607.035714
# Tamaulipas                        777.133333

# %%
grouped_restaurant_details = restaurant_details[["AVERAGE_DINE_IN_PER_MONTH", "STATE"]].groupby('STATE')
mean_updated = grouped_restaurant_details.transform(lambda x : x.fillna(x.mean()))
mean_updated["STATE"] = restaurant_details["STATE"]
mean_updated.loc[[20, 25, 33, 42], :  ]
# Out:
#     AVERAGE_DINE_IN_PER_MONTH            STATE
# 20                 607.035714  San Luis Potosi
# 25                 607.035714  San Luis Potosi
# 33                 607.035714  San Luis Potosi
# 42                 607.035714  San Luis Potosi

# %%
restaurant_details[["AVERAGE_DINE_IN_PER_MONTH"]].median()[0]
# Out:
# 675.5

# %%
average_dine_in_per_month_array = np.array(restaurant_details["AVERAGE_DINE_IN_PER_MONTH"])
imputer = SimpleImputer(strategy= "median")
restaurant_details['AVERAGE_DINE_IN_PER_MONTH_MEDIAN_IMPUTED'] = imputer.fit_transform(average_dine_in_per_month_array.reshape(-1,1))
restaurant_details.loc[[20, 25, 33, 42], ["AVERAGE_DINE_IN_PER_MONTH_MEDIAN_IMPUTED", "STATE"]]
# Out:
#     AVERAGE_DINE_IN_PER_MONTH_MEDIAN_IMPUTED            STATE
# 20                                     675.5  San Luis Potosi
# 25                                     675.5  San Luis Potosi
# 33                                     675.5  San Luis Potosi
# 42                                     675.5  San Luis Potosi

# %%
grouped_restaurant_details = restaurant_details[["AVERAGE_DINE_IN_PER_MONTH", "STATE"]].groupby('STATE')
median_updated = grouped_restaurant_details.transform(lambda x : x.fillna(x.median()))
median_updated["STATE"] = restaurant_details["STATE"]
median_updated.loc[[20, 25, 33, 42], :  ]
# Out:
#     AVERAGE_DINE_IN_PER_MONTH            STATE
# 20                      603.0  San Luis Potosi
# 25                      603.0  San Luis Potosi
# 33                      603.0  San Luis Potosi
# 42                      603.0  San Luis Potosi

# %%
restaurant_cuisine.columns.values
# Out:
# array(['placeID', 'Rcuisine'], dtype=object)

# %%
restaurant_details_cuisine = pd.merge(restaurant_details, restaurant_cuisine.set_index('placeID'), left_on='PLACEID', right_index=True, how = "inner")
restaurant_details_cuisine.columns.values
# Out:
# array(['PLACEID', 'NAME', 'ADDRESS', 'STATE', 'COUNTRY', 'ALCOHOL',
#        'SMOKING_AREA', 'PRICE', 'AREA', 'OTHER_SERVICES', 'REGION',
#        'AVERAGE_DINE_IN_PER_MONTH',
#        'AVERAGE_DINE_IN_PER_MONTH_MEAN_IMPUTED',
#        'AVERAGE_DINE_IN_PER_MONTH_MEDIAN_IMPUTED', 'Rcuisine'],
#       dtype=object)

# %%
restaurant_details_cuisine_parking = pd.merge(restaurant_details_cuisine, restaurant_parking.set_index('placeID'), left_on="PLACEID", right_index = True, how="inner" )
restaurant_details_cuisine_parking.columns.values
# Out:
# array(['PLACEID', 'NAME', 'ADDRESS', 'STATE', 'COUNTRY', 'ALCOHOL',
#        'SMOKING_AREA', 'PRICE', 'AREA', 'OTHER_SERVICES', 'REGION',
#        'AVERAGE_DINE_IN_PER_MONTH',
#        'AVERAGE_DINE_IN_PER_MONTH_MEAN_IMPUTED',
#        'AVERAGE_DINE_IN_PER_MONTH_MEDIAN_IMPUTED', 'Rcuisine',
#        'parking_lot'], dtype=object)

# %%
restaurant_details_cuisine_parking.loc[:, ["PLACEID", "NAME", "Rcuisine", "parking_lot"]].head()
# Out:
#    PLACEID                              NAME  Rcuisine parking_lot
# 0   134999                  Kiku Cuernavaca   Japanese        none
# 1   132825                  puesto de tacos    Mexican        none
# 2   135106       El Rincon de San Francisco    Mexican        none
# 3   132667   little pizza Emilio Portes Gil   Armenian        none
# 4   132613                    carnitas_mata    Mexican         yes

# %%
restaurant_details_cuisine_parking["Rcuisine"].value_counts()
# Out:
# Mexican             22
# Bar                 12
# Cafeteria            8
# Fast_Food            7
# Bar_Pub_Brewery      6
# Seafood              5
# Pizzeria             5
# American             4
# Japanese             4
# Burgers              4
# International        4
# Chinese              3
# Contemporary         2
# Italian              2
# Family               2
# Vietnamese           1
# Game                 1
# Breakfast-Brunch     1
# Cafe-Coffee_Shop     1
# Armenian             1
# Regional             1
# Bakery               1
# Name: Rcuisine, dtype: int64

# %%
restaurant_details_cuisine_parking["parking_lot"].value_counts()
# Out:
# none             44
# yes              38
# public           14
# valet parking     1
# Name: parking_lot, dtype: int64

# %%
subset  = restaurant_details_cuisine_parking.loc[(restaurant_details_cuisine_parking.Rcuisine == "Mexican") & (restaurant_details_cuisine_parking.parking_lot == "public"), ['NAME', 'Rcuisine', 'parking_lot']]
subset
# Out:
#                          NAME Rcuisine parking_lot
# 41    Hamburguesas La perica   Mexican      public
# 62         Gordas de morales   Mexican      public
# 80       Gorditas Doa Gloria   Mexican      public
# 89        Gorditas Dona Tota   Mexican      public
# 101     La Estrella de Dimas   Mexican      public

# %%
subset  = restaurant_details_cuisine_parking.loc[(restaurant_details_cuisine_parking.Rcuisine == "Mexican") | (restaurant_details_cuisine_parking.Rcuisine == "American"), ['NAME', 'Rcuisine', 'parking_lot']]
display(subset)

subset  = restaurant_details_cuisine_parking.loc[restaurant_details_cuisine_parking.Rcuisine.isin(["Mexican", "American"]) , ['NAME', 'Rcuisine', 'parking_lot']]
display(subset)
# Out:
#                                           NAME  Rcuisine parking_lot
# 1                             puesto de tacos    Mexican        none
# 2                  El Rincon de San Francisco    Mexican        none
# 4                               carnitas_mata    Mexican         yes
# 6                          Taqueria EL amigo     Mexican        none
# 19                             TACOS EL GUERO    Mexican        none
# 23                                        KFC   American         yes
# 34                 El Rincon de San Francisco    Mexican        none
# 41                     Hamburguesas La perica    Mexican      public
# 55    la Cochinita Pibil Restaurante Yucateco    Mexican         yes
# 58                           El Oceano Dorado    Mexican         yes
# 62                          Gordas de morales    Mexican      public
# 66         Cenaduria El Rincan de Tlaquepaque    Mexican        none
# 73                                 palomo tec    Mexican        none
# ...

# %%
consumer_survey.columns.values
# Out:
# array(['gender', 'smoker', 'drink_level', 'dress_preference', 'ambience',
#        'transport', 'marital_status', 'interest', 'personality',
#        'religion', 'activity', 'income', 'FRVPM', 'AERPM'], dtype=object)

# %%
subset = consumer_survey.loc[:, ['gender', 'smoker', 'marital_status', 'FRVPM']]
subset.head()
# consumer_survey.loc[0,['martial_status']]
# Out:
#    gender smoker marital_status  FRVPM
# 0    male  False         single     12
# 1  female  False         single     12
# 2  female  False         single      3
# 3    male  False         single     18
# 4  female  False         single     15

# %%
subset.sort_values(by = ['FRVPM'], ascending=True).head()
# Out:
#      gender smoker marital_status  FRVPM
# 133    male  False         single      2
# 130  female  False         single      2
# 22     male  False         single      2
# 108    male   True         single      2
# 45     male  False         single      2

# %%
subset.sort_values(by = ['FRVPM'], ascending=False).head()
# Out:
#      gender smoker marital_status  FRVPM
# 98     male  False         single     60
# 132    male  False         single     45
# 10   female  False         single     22
# 3      male  False         single     18
# 16   female  False         single     18

# %%
restaurant_details_cuisine_parking['parking_lot'].value_counts()
# Out:
# none             44
# yes              38
# public           14
# valet parking     1
# Name: parking_lot, dtype: int64

# %%
restaurant_details_cuisine_parking['parking_availability'] = restaurant_details_cuisine_parking['parking_lot'] != 'none'
restaurant_details_cuisine_parking.loc[:, ['PLACEID', 'NAME', 'Rcuisine', 'parking_lot', 'parking_availability']].head()
# Out:
#    PLACEID                              NAME  ... parking_lot parking_availability
# 0   134999                  Kiku Cuernavaca   ...        none                False
# 1   132825                  puesto de tacos   ...        none                False
# 2   135106       El Rincon de San Francisco   ...        none                False
# 3   132667   little pizza Emilio Portes Gil   ...        none                False
# 4   132613                    carnitas_mata   ...         yes                 True
#
# [5 rows x 5 columns]

# %%
restaurant_details_cuisine_parking['parking_availability'].value_counts()
# Out:
# True     53
# False    44
# Name: parking_availability, dtype: int64

# %%
user_rating.head()
# Out:
#   userID  placeID  food_rating  service_rating
# 0  U1077   135085            2               2
# 1  U1077   135038            2               1
# 2  U1077   132825            2               2
# 3  U1077   135060            2               2
# 4  U1068   135104            1               2

# %%
user_rating_melted = pd.melt(user_rating, id_vars=['userID', 'placeID'], value_vars=['food_rating', 'service_rating'], var_name='food/service', value_name='rating')

# %%
user_rating_melted.head()
# Out:
#   userID  placeID food/service  rating
# 0  U1077   135085  food_rating       2
# 1  U1077   135038  food_rating       2
# 2  U1077   132825  food_rating       2
# 3  U1077   135060  food_rating       2
# 4  U1068   135104  food_rating       1

# %%
user_rating_melted.tail()
# Out:
#      userID  placeID    food/service  rating
# 2317  U1043   132630  service_rating       1
# 2318  U1011   132715  service_rating       0
# 2319  U1068   132733  service_rating       0
# 2320  U1068   132594  service_rating       1
# 2321  U1068   132660  service_rating       0

# %%
pd.pivot_table(user_rating_melted, index='placeID', columns='food/service', values='rating', aggfunc='mean').head()
# Out:
# food/service  food_rating  service_rating
# placeID
# 132560               1.00        0.250000
# 132561               1.00        1.000000
# 132564               1.25        1.500000
# 132572               1.00        0.933333
# 132583               1.00        1.250000

# %% [markdown]
# ## Explore and Summarize data
# ## Exploring Quantitative Attributes
# Five Number Summary

# %%
five_number_summary = consumer_survey.FRVPM.describe()
five_number_summary
# Out:
# count    134.000000
# mean       9.067164
# std        6.906680
# min        2.000000
# 25%        5.000000
# 50%        8.000000
# 75%       12.000000
# max       60.000000
# Name: FRVPM, dtype: float64

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(y = consumer_survey['FRVPM'])
plt.title('Boxplot of FRVPM')
plt.show()

# %%
consumer_survey['FRVPM'].nlargest(3).values
# Out:
# array([60, 45, 22])

# %%
IQR = five_number_summary['75%'] - five_number_summary['25%']
upper_limit = five_number_summary['75%'] + (1.5 * IQR)
lower_limit = five_number_summary['25%'] - (1.5 * IQR)
display(IQR)
display(upper_limit)
display(lower_limit)
# Out:
# 7.0
# 22.5
# -5.5

# %% [markdown]
# ## Histogram

# %%
sns.distplot(consumer_survey['FRVPM'], kde=False)
plt.title('Histogram of FRVPM')
plt.xlabel('FRVPM')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Cross Tab

# %%
pd.crosstab(index = consumer_survey['gender'], columns='count', colnames=" ")
# Out:
#         count
# gender
# female     61
# male       73

# %%
pd.crosstab(index = consumer_survey['income'], columns='count', colnames=" ")
# Out:
#         count
# income
# high       16
# low        36
# medium     82

# %%
pd.crosstab(index = consumer_survey['FRVPM'] > 10, columns='count', colnames=" ")
# Out:
#        count
# FRVPM
# False     90
# True      44

# %%
pd.crosstab(index = restaurant_details['REGION'], columns='count', colnames=" ")
# Out:
#         count
# REGION
#  East      60
#  West      50

# %% [markdown]
# ## Bar Chart

# %%
consumer_survey['income'] = pd.Categorical(consumer_survey['income'], categories=['low', 'medium', 'high'], ordered=True)

# %%
sns.countplot(x = 'income', data = consumer_survey)
plt.title("Barchart of income")
plt.show()

# %%
subset = pd.DataFrame(consumer_survey.FRVPM > 10)
subset.columns = ['FRVPM>10']

sns.countplot(x = 'FRVPM>10', data = subset)
plt.title('FRVPM>10')
plt.show()

# %%
restaurant_details['AVERAGE_DINE_IN_PER_MONTH'] = mean_updated['AVERAGE_DINE_IN_PER_MONTH']

# %%
sns.boxplot(y = 'AVERAGE_DINE_IN_PER_MONTH', x = 'REGION', data = restaurant_details)
plt.title('East vs West AVERAGE_DINE_IN_PER_MONTH')
plt.show()

# %%
subset_East = restaurant_details.loc[(restaurant_details.REGION == 'East'), ['REGION', 'AVERAGE_DINE_IN_PER_MONTH']]
subset_West = restaurant_details.loc[(restaurant_details.REGION == 'West'), ['REGION', 'AVERAGE_DINE_IN_PER_MONTH']]

# %%
sns.distplot(subset_East['AVERAGE_DINE_IN_PER_MONTH'], color='red', kde=False, label='East')
sns.distplot(subset_West['AVERAGE_DINE_IN_PER_MONTH'], color='blue', kde=False, label='West')
plt.legend()
plt.xlabel('Average DineIn Per Month')
plt.ylabel('Frequency')
plt.title('East vs West frequency of Average DineIn Per Month')
plt.show()
