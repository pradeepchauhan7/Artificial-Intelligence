# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
# %matplotlib notebook

# %%
X =  np.array([[5,40], 
               [8, 82],
               [6, 52]], dtype=float)
y = np.array([[15], [24], [8]], dtype=float)  

X = X/np.max(X, axis=0)
y = y/np.max(y)

# %%
class Neural_Network(object):
  def __init__(self):
    self.inputsize = 2
    self.hiddensize = 3
    self.outputsize = 1

# %%
fuel = 5/8
dist = 40/82
budget = 15/24

# %%
fuelw1 = 0.3 
fuelw2 =  0.2
fuelw3 = 0.6

# %%
distw1 = 0.22
distw2 = 0.56
distw3 = 0.7

# %%
HN1 = (fuel * fuelw1) + (dist * distw1)
HN2 = (fuel * fuelw2) + (dist * distw2)
HN3 = (fuel * fuelw3) + (dist * distw3)

# %%
def sigmoid(s):
  return 1/(1+np.exp(-s))

# %%
s1 = sigmoid(HN1)
s2 = sigmoid(HN2)
s3 = sigmoid(HN3)

# %%
Hw1 = 0.21
Hw2 = 0.45
Hw3 = 0.85

# %%
o = HN1 * Hw1 + HN2 * Hw2 + HN3 * Hw3

# %%
o
# Out:
# 0.8500823170731707
